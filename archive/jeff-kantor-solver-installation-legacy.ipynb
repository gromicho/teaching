# %% [markdown]
# # Jeff Kantor's solver-installation notebook (historical archive)
#
# **Historical reference - original work by Jeffrey (Jeff) Kantor.** Restored for attribution and preservation at Joaquim Gromicho's request on 31 August 2026.
#
# > **Read as historical material; do not use Run all as a setup procedure.** This is unfinished cross-platform solver-installation work, not current course instructions. Its code, experiments, solver/licence table and external links have been preserved, including known incomplete cells. Historical statements are not current recommendations. Installation cells can modify the environment or restart the kernel. This notebook is excluded from automated execution and has not been validated on today's Colab runtime.
#
# For supported course setup, use the [current setup guide](https://github.com/gromicho/teaching/blob/main/docs/SETUP.md). The [archive index](https://github.com/gromicho/teaching/blob/main/archive/README.md) explains provenance and preservation.
#
# _Migrated from the course Drive notebook `18bKeFyihLXDxdZajDWpjOT2nhyrnt-IQ` on 28 August 2026; recovered from the former public AABW repository at commit `e95551e8d18095d60486ed5cc6fab67db59a0023`. Jeff's original tribute and all subsequent cell source text remain unchanged. No new licence is asserted._

# %% [markdown]
# # A legacy from our great friend [Jeff Kantor](https://news.nd.edu/news/in-memoriam-jeffrey-kantor-former-vice-president-associate-provost-and-dean)
#
# The code and information on this notebook has been developed by Jeff as one of his last projects.
#
# In the end, it did not make it to production, as you may see on the [online companion](https://mobook.github.io/MO-book/intro.html) to our book.

# %% [markdown]
# # Installing Pyomo and Solvers
#
# To facilitate the use of Pyomo, a module of 'helper' functions has been developed to support the installation and testing of Pyomo modeling environemnt, the Idaes toolkit for processs systems engineering, and a collection of open-source and free versions of commercial solvers for use with Pyomo and Idaes.

# %% [markdown]
# ## Available Solvers
#
# | Solver | License | Limits | Threads | LP | IP | MILP | QP | MIQP | QCQP | MIQCQP | SOCP | MISCOP | NLP | MINLP |
# | :-- | :-- | :-- | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: |  :--: |  :--: |  :--: | :--: |
# | [GLPK](https://en.wikibooks.org/wiki/GLPK) | GPL 3 | | | &#10003; | &#10003; | &#10003; |
# | [CBC](https://github.com/coin-or/Cbc) | EPL 2 | | &#10003; | &#10003; | &#10003; | &#10003; | |
# | [ipopt](https://github.com/coin-or/Ipopt) | EPL 2 | | | &#10003; | | | &#10003; | | &#10003; | | &#10003; | | &#10003; | |
# | [bonmin](https://github.com/coin-or/Bonmin) | EPL 1 | | | &#10003; | &#10003; |  &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; |  &#10003; | &#10003; |
# | [couenne](https://github.com/coin-or/Couenne) | EPL 1 | | | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; |
# | [scip](https://www.scipopt.org/index.php#license)$^*$ | ZIB |  Academic License | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | | |
# | [gecode](https://github.com/Gecode/gecode) | MIT | | | | &#10003;  | | | | |
# | [gurobi](https://pypi.org/project/gurobipy/) <br> evaluation | restricted | 2000 variables <br> 2000 constraints | &#10003; | &#10003;  | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | | |
# | [mosek](https://solve.mosek.com/web/index.html) <br> OptServer Demo | restricted | 1000 variables <br> 1000 constraints | &#10003; | &#10003;  | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | | |
# | [cplex](https://pypi.org/project/cplex/) <br> community edition | restricted | 1000 variables <br> 1000 constraints | &#10003; | &#10003;  | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003;
# | [xpress](https://pypi.org/project/xpress/) <br> community edition | [restricted](https://community.fico.com/s/fico-xpress-optimization-licensing-optio) | 5000 variables <br> and constraints | &#10003; | &#10003;  | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; | &#10003; |
#
# $^*$ Be aware the installation script for SCIP on Google Colab installs conda and restarts the python kernel.

# %% [markdown]
# ## Installation scripts
#
# `pyomo-helper` is organized as a single python module containing separate functions to install packages for Pyomo, the Ideas toolkit, and each of the solvers available for Google Colab. Each installation function performs the following tasks:
#
# * Checks if the package has been previously installed in Google Colab. If so, the function reports the previous installation and returns `True`.
#
# * If the package has not be installed, the package is downloaded and installed using a publically documented method for installing that package.
#
# * After completing installation, a check is performed to test for a successful installation. The function returns `True` if the installation is confirmed, otherwise returns `False`.

# %%
import shutil
import sys
import os.path
import os
import subprocess

def _check_available(executable_name):
    """Return True if the executable_name is found in the search path."""
    return (shutil.which(executable_name) is not None) or os.path.isfile(executable_name)

def package_available(package_name):
    """Return True if package_name is installed."""
    return _check_available("glpsol") if package_name == "glpk" else _check_available(package_name)

def package_found(package_name):
    """Print message confirming that package was found, then return True or False."""
    is_available = package_available(package_name)
    if is_available:
        print(f"{package_name} was previously installed")
    return is_available

def package_confirm(package_name):
    """Confirm package is available after installation."""
    if package_available(package_name):
        print("installation successful")
        return True
    else:
        print("installation failed")
        return False

def on_colab():
    """Return True if running on Google Colab."""
    return "google.colab" in sys.modules

def install_pyomo():
    """Install pyomo from idaes_pse to include enhanced LA solvers."""
    if package_found("pyomo"):
        return True
    print("Installing pyomo from idaes_pse via pip ... ", end="")
    os.system("pip install -q idaes_pse")
    return package_confirm("pyomo")

def install_idaes():
    if package_found("idaes"):
        return
    print("Installing idaes from idaes_pse via pip ... ", end="")
    os.system("pip install -q idaes_pse")
    return package_confirm("idaes")

def install_ipopt():
    if package_found("ipopt"):
        return True

    # try idaes version of ipopt with HSL solvers
    if on_colab():
        # Install idaes solvers
        print("Installing ipopt and k_aug on Google Colab via idaes get-extensions ... ", end="")
        os.system("idaes get-extensions")

        # Add symbolic link for idaes solvers
        os.system("ln -s /root/.idaes/bin/ipopt ipopt")
        os.system("ln -s /root/.idaes/bin/k_aug k_aug")

    # check again
    if package_confirm("ipopt"):
        return True

    # try coin-OR version of ipopt with mumps solvers
    if on_colab():
        print("Installing ipopt on Google Colab via zip file ... ", end="")
        os.system('wget -N -q "https://ampl.com/dl/open/ipopt/ipopt-linux64.zip"')
        os.system('!unzip -o -q ipopt-linux64')
    else:
        print("Installing Ipopt via conda ... ", end="")
        os.system('conda install -c conda-forge ipopt')
    return package_confirm("ipopt")

def install_glpk():
    if package_found("glpk"):
        return True
    if on_colab():
        print("Installing glpk on Google Colab via apt-get ... ", end="")
        os.system('apt-get install -y -qq glpk-utils')
    else:
        print("Installing glpk via conda ... ", end="")
        os.system('conda install -c conda-forge glpk')
    return package_confirm("glpk")

def install_cbc():
    if package_found("cbc"):
        return True
    if on_colab():
        print("Installing cbc on Google Colab via zip file ... ", end="")
        os.system('wget -N -q "https://ampl.com/dl/open/cbc/cbc-linux64.zip"')
        os.system('unzip -o -q cbc-linux64')
    else:
        print("Installing cbc via apt-get ... ", end="")
        os.system('apt-get install -y -qq coinor-cbc')
    return package_confirm("cbc")

def install_bonmin():
    if package_found("bonmin"):
        return True
    if on_colab():
        print("Installing bonmin on Google Colab via zip file ... ", end="")
        os.system('wget -N -q "https://ampl.com/dl/open/bonmin/bonmin-linux64.zip"')
        os.system('unzip -o -q bonmin-linux64')
    else:
        print("No procedure implemented to install bonmin ... ", end="")
    return package_confirm("bonmin")

def install_couenne():
    if package_found("couenne"):
        return
    if on_colab():
        print("Installing couenne on Google Colab via via zip file ... ", end="")
        os.system('wget -N -q "https://ampl.com/dl/open/couenne/couenne-linux64.zip"')
        os.system('unzip -o -q couenne-linux64')
    else:
        print("No procedure implemented to install couenne ... ", end="")
    return package_confirm("couenne")

def install_gecode():
    if package_found("gecode"):
        return
    if on_colab():
        print("Installing gecode on Google Colab via via zip file ... ", end="")
        os.system('wget -N -q "https://ampl.com/dl/open/gecode/gecode-linux64.zip"')
        os.system('unzip -o -q gecode-linux64')
    else:
        print("No procedure implemented to install gecode ... ", end="")
    return package_confirm("gecode")

def install_scip():
    if package_found("scip"):
        return

    if on_colab():
        print("Installing scip on Google Colab via conda ... ", end="")
        try:
            import condacolab
        except:
            os.system("pip install -q condacolab")
            import condacolab
            condacolab.install()
        os.system("conda install -y pyscipopt")

    return package_confirm("scip")

def install_gurobi():
    try:
        import gurobipy
    except ImportError:
        pass
    else:
        print("gurobi was previously installed")
        return

    if on_colab():
        print("Installing gurobi on Google Colab via pip ... ", end="")
        os.system("pip install gurobipy")
    else:
        print("Consult gurobi.com for installation procedures ... ", end="")

    try:
        import gurobipy
        print("installation successful")
        return True
    except ImportError:
        print("installation failed")
        return False

def install_cplex():
    try:
        import cplex
    except ImportError:
        pass
    else:
        print("cplex was previously installed")
        return

    if on_colab():
        print("Installing cplex on Google Colab via pip ... ", end="")
        os.system("pip install cplex")
    else:
        print("Consult ibm.com for installation procedures ... ", end="")

    try:
        import cplex
        print("installation successful")
        return True
    except ImportError:
        print("installation failed")
        return False

def install_mosek():
    try:
        import mosek.fusion
    except ImportError:
        pass
    else:
        print("mosek was previously installed")
        return

    if on_colab():
        print("Installing mosek on Google Colab via pip ... ", end="")
        os.system("pip install mosek")
    else:
        print("Consult docs.mosek.com for installation procedures ... ", end="")

    try:
        import mosek.fusion
        print("installation successful")
        return True
    except ImportError:
        print("installation failed.")
        return False

def install_xpress():
    try:
        import xpress
    except ImportError:
        pass
    else:
        print("Xpress was previously installed")
        return

    if on_colab():
        print("Installing xpress on Google Colab via pip ... ", end="")
        os.system("pip install xpress")
    else:
        print("Installing xpress via conda ... ", end="")
        os.system("conda install -c fico-xpress xpress")

    try:
        import xpress
        print("installation successful")
        return True
    except ImportError:
        print("installation failed")
        return False


# install modeling
install_idaes()
install_pyomo()

# install solvers
install_ipopt()
install_glpk()
install_cbc()
install_bonmin()
install_couenne()
install_gecode()
install_scip()
install_gurobi()
install_cplex()
install_mosek()
install_xpress()

# %% [markdown]
# ## Confirming Correct Operation

# %% [markdown]
# ### LP Solvers

# %%
import pyomo.environ as pyo

def lp_model():
    m = pyo.ConcreteModel("test")
    m.x = pyo.Var(bounds=(0, 10))
    m.y = pyo.Var(bounds=(0, 10))

    @m .Constraint()
    def c(m):
        return m.x + m.y <= 15

    @m.Objective(sense=pyo.maximize)
    def obj(m):
        return m.x + 2*m.y

    return m

lp_solvers = ["glpk", "cbc", "ipopt", "bonmin", "couenne", "scip", "gurobi_direct", "cplex_direct", "xpress_direct"]

lp = lp_model()
for solver in lp_solvers:
    pyo.SolverFactory(solver).solve(lp)
    print(f"{solver:15s} {lp.obj():0.6f}")

# %%
solvers = {
    "glpk": {},
    "cbc": {"threads": 4},
    "ipopt": {},
    "mosek": {"sparam.remote_optserver_host":"http://solve.mosek.com:30080"},
    "mosek_direct": {"sparam.remote_optserver_host":"http://solve.mosek.com:30080"},
    "bonmin": {},
    "couenne": {},
    "scip": {},
    "gurobi_direct": {},
    "cplex_direct":{},
    "xpress_direct":{},
    "gecode": {},
}

lp = lp_model()
for solver in solvers:
    try:
        pyo.SolverFactory(solver).solve(lp, options=solvers[solver])
        print(f"{solver:15s} {lp.obj():0.6f}")
    except:
        print(f"{solver:15s} failed")

# %% [markdown]
# ## NLP Solvers

# %%
import pyomo.environ as pyo

def rosenbrock(n=2, x0 = 1.0):

    m = pyo.ConcreteModel("Rosenbrock")
    m.N = pyo.Set(initialize=range(1, n+1))
    m.N1 = pyo.Set(initialize=range(1, n))
    m.x = pyo.Var(m.N, bounds=(-5, 10))

    @m.Objective(sense=pyo.minimize)
    def obj(m):
        return sum((x0 - m.x[k])**2 + 100*(m.x[k+1] - m.x[k]**2)**2 for k in m.N1)

    return m

nlp = rosenbrock(4)
nlp_solvers = ["bonmin", "ipopt", "couenne", "scip"] #, "xpress_direct"]

for solver in nlp_solvers:
    print(f"\n{solver:15s}")
    try:
        results = pyo.SolverFactory(solver).solve(nlp, report_timing=True)
        print()
    except:
        print(" exception reported")
    else:
        print(f"  obj = {nlp.obj():0.6f}")
        for k in nlp.N:
            print(f" x[{k}] = {nlp.x[k]():0.6f}")

# %%
import pyomo.environ as pyo
solver = pyo.SolverFactory('xpress')
solver.solve(lp, options={"threads": 4}).write()

# %%
import sys
import os
if "google.colab" in sys.modules:
    if not os.path.isfile("helper.py"):
        # !wget -q "https://raw.githubusercontent.com/jckantor/MO-book/main/python/helper.py"
    import helper
    helper.install_pyomo()
    helper.install_ipopt()
    helper.install_glpk()
    helper.install_cbc()
    helper.install_bonmin()
    helper.install_couenne()
    helper.install_gecode()
 #   helper.install_gurobi()
 #   helper.install_mosek()

# %%
g!wget "https://raw.githubusercontent.com/jckantor/MO-book/intro.md"

# %%
import shutil

shutil.which('mosek_direct')

# %%
# !mosek

# %%
os.system("mosek")

# %%
# !pip install xpress

# %%
import xpress

# %%
# !pip install pySCIPOpt

# %%
# !pip install scip

# %%
# !conda install -channel conda-forge pyscipopt

# %%
# !which scip

# %%
import condacolab
condacolab.install()
# !conda install pyscipopt

# %%
import pyscipopt

# %%
Solver
