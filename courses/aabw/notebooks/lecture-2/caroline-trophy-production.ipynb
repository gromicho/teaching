# %% [markdown]
# # Caroline: continue to the complete lesson
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gromicho/teaching/blob/main/courses/aabw/notebooks/lecture-2/caroline-trophy-production.ipynb) [![Open in Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/gromicho/teaching/main?urlpath=tree/courses/aabw/notebooks/lecture-2/caroline-trophy-production.ipynb)
#
# **The complete Caroline lesson is now maintained in one place.**
#
# [Open the complete lesson in Colab](https://colab.research.google.com/github/gromicho/teaching/blob/main/foundations/optimization/caroline-production-planning.ipynb)
#
# [Read the complete notebook on GitHub](https://github.com/gromicho/teaching/blob/main/foundations/optimization/caroline-production-planning.ipynb)
#
# Joaquim Gromicho’s trophy-production example retains the full progression from
# the scalar model to indexed formulations, actual Ipopt/CBC/HiGHS comparisons,
# resource sensitivity and dual values. Existing lecture links can continue to
# use this page; new links should point directly to the complete lesson.
