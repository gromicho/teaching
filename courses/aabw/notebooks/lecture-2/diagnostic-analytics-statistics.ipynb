# %% [markdown]
# # Advanced Analytics for a Better World — Lecture 2
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gromicho/teaching/blob/main/courses/aabw/notebooks/lecture-2/diagnostic-analytics-statistics.ipynb) [![Open in Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/gromicho/teaching/main?urlpath=tree/courses/aabw/notebooks/lecture-2/diagnostic-analytics-statistics.ipynb)
#
# > Original Lecture 2 notebook, retained with its author attribution and content.

# %% [markdown]
# <img align='left' width='180' src='https://raw.githubusercontent.com/gromicho/teaching/main/courses/aabw/notebooks/lecture-2/assets/aabw-logo.png'>
#
# ----------------------
#
# This notebook is part of _a bird's eye flight over the Python analytics landscape_.
#
# ---
#  > We make use of self-contained Jupyter notebooks hosted by [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
#   Notebooks deployed on `colab` require neither python nor other dependencies to be installed on your own machine, you only need a browser (preferably `chrome`) and you may also need a google account if you want to execute them.
#
# ---
#
# The notebooks make extensive use of [markdown](https://en.wikipedia.org/wiki/Markdown) of which [here](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet) you may find a very comprehensive summary. May you like a document that you can print, fold, and take with you then you may like to check [this](https://enterprise.github.com/downloads/en/markdown-cheatsheet.pdf).

# %% [markdown]
# # Diagnostic analytics: the significance of statistics

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
url = 'https://raw.githubusercontent.com/gromicho/teaching/main/data/weight-height.csv'
df = pd.read_csv(url)

# %%
df

# %% [markdown]
# The numbers above are in [imperial](https://www.interexchange.org/articles/career-training-usa/2012/05/24/imperial-vs-metric-system/), may we prefer [metric](https://www.interexchange.org/articles/career-training-usa/2012/05/24/imperial-vs-metric-system/) then its quite simple.

# %%
df.Height = df.Height * 2.54
df.Weight = df.Weight * 0.45359237

# %%
df

# %%
df[df.Gender == 'Female'].describe()

# %%
df[df.Gender == 'Male'].describe()

# %%
sns.displot( data=df, hue='Gender', x='Height', fill=True )

# %%
sns.displot( data=df, hue='Gender', x='Height', fill=True, kde=True )

# %%
sns.displot( data=df, hue='Gender', x='Height', fill=True, kind='kde' )

# %%
sns.displot( data=df, hue='Gender', x='Weight', fill=True, kind='kde' )

# %% [markdown]
# Are these variances the same? We can use [Levene's test](https://en.wikipedia.org/wiki/Levene%27s_test).

# %%
stats.levene(df[df.Gender == 'Male'].Height,df[df.Gender == 'Female'].Height)

# %% [markdown]
# Such p-value renders the hipothesis to be so unlikely that we should reject it.

# %%
stats.ttest_ind(df[df.Gender == 'Male'].Height,df[df.Gender == 'Female'].Height,equal_var=False)

# %% [markdown]
# Also the average height of a men and a women are significantly different as well.
