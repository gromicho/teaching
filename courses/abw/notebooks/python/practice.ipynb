# %% [markdown]
# # Python practice: explain, predict, check
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gromicho/teaching/blob/main/courses/abw/notebooks/python/practice.ipynb)
#
# **Exercise** · UvA Business Analytics teaching collection
#
# Work through the questions before running each cell. Explain the result, check its assumptions, and change one input to test your understanding.

# %% [markdown]
# ## Preparation
# Use the shared Python primer and indexing notebook. These exercises are course practice, not a replacement for the official booklet. Write a prediction before you run a cell; test both an ordinary case and an edge case.
#
# 1. Write a function that sums the positive values in a list. What should happen for an empty list?
# 2. Build a dictionary from product names to prices. Check for missing names explicitly.
# 3. Compute the cost of a production plan using its product quantities.
# 4. Explain the difference between two names referring to the same list and two equal lists.
# 5. Construct a small table, reorder its rows, and show when positional multiplication would give the wrong result.

# %%
def sum_positive(values):
    # TODO: return the sum of positive entries.
    return None

# %% [markdown]
# ## Self-check after your attempt
# Try `[3, -2, 4, 0]`, `[]` and `[-1, -3]`. Explain why each expected answer follows from your specification. Write your own assertions once the function is complete.
#
# > **Optional UvA AI Chat prompt:** Ask me to trace my function on a small example before giving feedback. If it fails, help me design a counterexample. Do not replace my attempt with a complete answer.
#
# ## Exam preparation
# Revisit the reasoning without a notebook or AI. The ABW exam is invigilated, pen and paper only. The only permitted device is a UvA-approved calculator with no connectivity.
