# %% [markdown]
# # Python primer
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gromicho/teaching/blob/main/foundations/python/python-primer.ipynb)
#
# **Worked Example** · UvA Business Analytics teaching collection
#
# Work through the questions before running each cell. Explain the result, check its assumptions, and change one input to test your understanding.

# %%
print('Hello world!')

# %%
# Predict the endpoints of range(1, 11), then run the cell.

numbers = list(range(1,11))

# %%
numbers

# %%
numbers = 'Hello World!'

# %%
numbers

# %% [markdown]
# # Learn Python Programming

# %% [markdown]
# The materials below were obtained from [Programiz](https://www.programiz.com/python-programming). It is however only a selection of the most important things to know, we do encourage you to follow the rest of the tutorial if the excercises below are easy for you or if you want to become better at Python!

# %% [markdown]
# # Variables
#
# For more information please refer to the section on [Python Variables and Literals](https://www.programiz.com/python-programming/variables-constants-literals).

# %% [markdown]
# A variable is a named location used to store data in the memory. It is helpful to think of variables as a container that holds data that can be changed later in the program. For example, here we create a variable named `number`, to which we assign a value of `10`.

# %%
number = 13

# %%
number

# %% [markdown]
# As you can see above, you can use the assignment operator `=` to assign a value to a variable. Values of variables can be printed by using a `print()` statement.

# %%
print(number)

# %% [markdown]
# Initially, the value of `number` was `10`. We can later still change it to any value we want.

# %%
number = 1.1
print(number)

# %% [markdown]
# It is also possible to assign multiple values to multiple variables, as long as the number of variables and values is the same.

# %%
a, b, c = 5, 3.2, "Hello"

print (a)
print (b)
print (c)

# %% [markdown]
# If we want to assign the same value to multiple variables at once, we can do this as:

# %%
x = y = z = "same"

print (x)
print (y)
print (z)

# %%
y = 2

# %%
print (x)
print (y)
print (z)

# %% [markdown]
# # Operators
#
# For more information please refer to the section on [Python Operators](https://www.programiz.com/python-programming/operators).

# %% [markdown]
# ### Arithmetic operators
# Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication, etc.

# %% [markdown]
# | Operator | Meaning |
# |----------|---------|
# | + | Add |
# | - | Subtract |
# | * | Multiply |
# | / | Divide |
# | % | Modulus |
# | // | Floor division |
# | ** | Exponent |

# %%
x = 15
y = 4

print('x + y =', x+y)
print('x - y =', x-y)
print('x * y =', x*y)
print('x / y =', x/y)
print('x // y =', x//y)
print('x ** y =', x**y)

# %% [markdown]
# ### Comparison operators
# Comparison operators are used to compare values. It returns either True or False according to the condition.
#
# | Operator | Meaning |
# |----------|---------|
# | > | True if left operand is **greater than** the right |
# | < | True if left operand is **less than** the right |
# | == | True if both operands are **equal** |
# | != | True if operands are **not equal** |
# | >= | True if left operand is **greater** than or **equal** to the right |
# | <= | True if left operand is **less** than or **equal** to the right |

# %%
x = 10
y = 12

print('x > y is',x>y)
print('x < y is',x<y)
print('x == y is',x==y)
print('x != y is',x!=y)
print('x >= y is',x>=y)
print('x <= y is',x<=y)

# %% [markdown]
# ### Logical operators
# Logical operators are the and, or, not operators.
#
# | Operator | Meaning |
# |----------|---------|
# | and | True if both the operands are true |
# | or | True if either of the operands is true |
# | not | True if operand is false |

# %%
x = True
y = False

print('x and y is', x and y)
print('x or y is', x or y)
print('not x is', not x)
print('not 3 == 4 is', not (3 == 4))

# %% [markdown]
# ### Assignment operators
#
# As we have already seen at the start of this notebook, assignment operators are used in Python to assign values to variables. There are various compound operators in Python like a += 5 that adds to the variable and later assigns the same. It is equivalent to a = a + 5.
#
# | Operator | Example | Equivalent to |
# |---|-------|--------|
# | = | x = 5 | x = 5 |
# | += | x += 5 | x = x + 5 |
# | -= | x -= 5 | x = x - 5 |
# | *= | x *= 5 | x = x * 5 |
# | /= | x /= 5 | x = x / 5 |
# | %= | x %= 5 | x = x % 5 |
# | //= | x //= 5 | x = x // 5 |
# | **= | x **= 5 | x = x ** 5 |

# %% [markdown]
# ### Special operators
#
# Python language offers some special types of operators like the identity operator or the membership operator.
#
# | Operator | Meaning |
# |----------|---------|
# | is | True if the operands are identical |
# | is not | True if the operands are not identical |
# | in | True if value/variable is found in the sequence |
# | not in | True if value/variable is not found in the sequence |

# %%
x1 = 5
y1 = 5
x2 = 'Hello'
y2 = 'Hello'
x3 = [1,2,3]
y3 = [1,2,3]

print(x1 is not y1)
print(x2 is y2)
print(x3 is y3)

# %% [markdown]
# Here, we see that x1 and y1 are integers of the same values, so they are equal as well as identical. Same is the case with x2 and y2 (strings), but x3 and y3 are lists. They are equal but not identical. It is because the interpreter locates them separately in memory although they are equal.

# %%
x = 'Hello world'
y = {1:'a',2:'b'}

print('H' in x)
print('hello' not in x)
print(1 in y)
print('a' in y)

# %% [markdown]
# Here, 'H' is in x but 'hello' is not present in x (remember, Python is case sensitive). Similarly, 1 is key and 'a' is the value in dictionary y. Hence, 'a' in y returns False.

# %% [markdown]
# # Comments
#
# For more information please refer to the section on [Python Comments](https://www.programiz.com/python-programming/statement-indentation-comments).
#
# Comments are very important while writing a program. They describe what is going on inside a program, so that a person looking at the source code does not have a hard time figuring it out. You might forget the key details of the program you just wrote in a month's time. So taking the time to explain these concepts in the form of comments is always fruitful.
#
# In Python, we use the hash (#) symbol to start writing a comment (shortcut for commenting a line = ctrl+/). Comments are for programmers to better understand a program. They will ignored by Python when executed the code.

# %%
# This is a comment
# print out Hello
print('Hello')

# %% [markdown]
# # Data Types
#
# For more information please refer to the section on [Python Data Types](https://www.programiz.com/python-programming/variables-datatypes).
#
# Every value in Python has a datatype. Since everything is an object in Python programming, data types are actually classes and variables are instance (object) of these classes. There are various data types in Python. Some of the important types are listed below.

# %% [markdown]
# ### Numbers
#
# Integers, floating point numbers and complex numbers fall under Python numbers category. They are defined as `int`, `float` classes in Python. We can use the type() function to know which class a variable or a value belongs to.
#
# Integers can be of any length, it is only limited by the memory available. A floating-point number is accurate up to 15 decimal places (notice that the variable `b` below is truncated). Integer and floating points are separated by decimal points. 1 is an integer, 1.0 is a floating-point number. Complex numbers are written in the form, `x + yj`, where x is the real part and y is the imaginary part. Here are some examples.

# %%
a = 5
print(a, "is of type", type(a))

b = 0.2
print(b, "is of type", type(b))

c = 1234567890123456789
print(c, "is of type", type(c))

d = 0.123456789012345689123
print(d, "is of type", type(d))

e = 1+2j
print(e, "is complex number?", isinstance(1+2j,complex), 'the type is', type(e))

# %% [markdown]
# ### List
#
# List is an ordered sequence of items. It is one of the most used datatype in Python and is very flexible. All the items in a list do not need to be of the same type. Declaring a list is pretty straight forward. Items separated by commas are enclosed within brackets `[ ]`.

# %%
a = [1, 2.2, 'python']
b = [5,10,15,20,25,30,35,40]

# %% [markdown]
# We can use the slicing operator `[ ]` to extract an item or a range of items from a list. The index starts from 0 in Python.

# %%
print("a[2] = ", a[2])
print("a[5:] = ", a[1:])
print("a[-1] = ", a[-1])
print("b[:3] = ", b[:3])
print("b[2:4] = ", b[2:4])
print("b[-3:] = ", b[-3:])

# %% [markdown]
# Lists are mutable, meaning, the value of elements of a list can be altered.

# %%
a = [1, 2, 3]
a[2] = 4
print(a)

# %% [markdown]
# ### Tuple
#
# Tuple is an ordered sequence of items same as a list. The only difference is that tuples are immutable. Tuples once created cannot be modified. Tuples are used to write-protect data and are usually faster than lists as they cannot change dynamically. It is defined within parentheses `(_)` where items are separated by commas.

# %%
t = (5,'program', 2)
print("t = ", t)
print("t[1] = ", t[1])
print("t[0:3] = ", t[0:2])

# %%
# Tuples are immutable. Demonstrate the expected error without stopping Run all.
try:
    t[0] = 10
except TypeError as error:
    print(f"Expected TypeError: {error}")

# %% [markdown]
# ### String
#
# String is sequence of Unicode characters. We can use single quotes `'_'` or double quotes `"_"` to represent strings. Multi-line strings can be denoted using triple quotes, `'''_'''` or `"""_"""`.

# %%
s = "This is a string"
print(s)

s = '''A multiline
string'''
print(s)

# %% [markdown]
# Just like a list and tuple, the slicing operator `[ ]` can be used with strings. Strings, however, are immutable.

# %%
s = 'Hello world!'

print("s[4] = ", s[4])
print("s[6:11] = ", s[6:11])

# %%
# Strings are immutable. Demonstrate the expected error safely.
try:
    s[5] = "d"
except TypeError as error:
    print(f"Expected TypeError: {error}")

# %% [markdown]
# ### Set
#
# Set is an unordered collection of unique items. Set is defined by values separated by comma inside braces `{_}`. Items in a set are not ordered. Since, set are unordered collection, indexing has no meaning. Hence, the slicing operator `[_]` does not work.
#
#
# We can perform set operations like union, intersection on two sets. Sets have unique values. They eliminate duplicates.

# %%
a = {5,2,3,1,4}

print("a = ", a)
print(type(a))

# %%
b = {1, 2, 2, 3, 3, 3}
print(b)
try:
    print(b[1])
except TypeError as error:
    print(f"Expected TypeError because sets are not subscriptable: {error}")

# %% [markdown]
# Sets make set operations convenient and efficient, for instance:

# %%
a & b

# %%
a | b

# %%
2 in a

# %% [markdown]
# ### Dictionary
#
# Dictionary is an insertion-ordered collection of key-value pairs. Dictionaries are optimized for retrieving data. We must know the key to retrieve the value (but not the other way around!). In Python, dictionaries are defined within braces `{_:_}` with each item being a pair in the form `key:value`. Key and value can be of any type.

# %%
d = {
    1:'one',
    2:'two',
    'key':5,
    'x':'y'
}

print(type(d))
print("d[1] = ", d[1])
print("d['key'] = ", d['key'])
print("d['x'] = ", d['x'])

# %% [markdown]
# All keys of a dictionary must be unique. If a value is assigned to a key that already existed, the value of that key is replaced by the newly assigned value.

# %%
d[1] = 'new'

print(d)

# %% [markdown]
# ### Conversion between data types
#
# We can convert between different data types by using different type conversion functions like `int()`, `float()`, `str()`, etc.

# %%
print(float(5))
print(int(10.6))
print(float('2.5'))
print(str(25))

# %% [markdown]
# Conversion to and from string must contain compatible values.

# %%
try:
    print(int("1p"))
except ValueError as error:
    print(f"Expected ValueError for a non-numeric string: {error}")

# %%
print(set([1,2,3]))
print(tuple({5,6,7}))
print(list('hello'))

# %% [markdown]
# # `if` statement
#
# For more information see [Python if...else Statement](https://www.programiz.com/python-programming/if-elif-else).
#
# Decision making is required when we want to execute a code only if a certain condition is satisfied. The `if…elif…else` statement is used in Python for decision making. Here, the program evaluates the test expression and will execute statement(s) only if the test expression is `True`. If the test expression is `False`, the statement(s) is not executed. Note: in Python, the body of the if statement is indicated by the indentation.
#
# In the example below, `num > 0` is the test expression. The body of if is executed only if this evaluates to `True`. When the variable num is equal to `3`, test expression is `True` and statements inside the body of if are executed. If the variable num is equal to `-1`, test expression is `False` and statements inside the body of if are skipped. Two of the `print(_)` statements fall outside of the if block (unindented). Hence, it is executed regardless of the test expression.

# %%
num = 3
if num > 0:
    print(num, "is a positive number.")
print("This is always printed.")

num = -1
if num > 0:
    print(num, "is a positive number.")

print("This is also always printed.")

# %% [markdown]
# The `if..else` statement evaluates the `else` part only when the `if` part is `False`. In the example below, when `num` is equal to `3`, the test expression is `True` and the body of `if` is executed and the body of `else` is skipped. If num is equal to -5, the test expression is `False` and the body of `else` is executed and the body of `if` is skipped. If num is equal to 0, the test expression is `True` and body of `if` is executed and body of `else` is skipped.

# %%
num = 3

# Try these two variations as well.
# num = -5
# num = 0

if num >= 0:
    print("Positive or Zero")
else:
    print("Negative number")

# %% [markdown]
# The `elif` is short for `else if`. It allows us to check for multiple expressions. If the condition for `if` is `False`, it checks the condition of the next `elif` block and so on. If all the conditions are `False`, the body of `else` is executed. Only one block among the several `if...elif...else` blocks is executed according to the condition.

# %%
'''In this program,
we check if the number is positive or
negative or zero and
display an appropriate message'''

num = 3.4

# Try these two variations as well:
# num = 0
# num = -4.5

if num > 0:
    print("Positive number")
elif num == 0:
    print("Zero")
else:
    print("Negative number")

# %% [markdown]
# We can have a `if...elif...else` statement inside another `if...elif...else` statement. This is called nesting in computer programming. Any number of these statements can be nested inside one another. Indentation is the only way to figure out the level of nesting. They can get confusing, so they must be avoided unless necessary.

# %%
'''In this program, we input a number
check if the number is positive or
negative or zero and display
an appropriate message
This time we use nested if statement'''

num = -1.0  # Change this value to explore the branches without interactive input.
if num >= 0:
    if num == 0:
        print("Zero")
    else:
        print("Positive number")
else:
    print("Negative number")

# %% [markdown]
# # `for` loop
#
# For more information see [Python for Loop](https://www.programiz.com/python-programming/for-loop).
#
# The for loop in Python is used to iterate over a sequence (list, tuple, string) or other iterable objects. Iterating over a sequence is called traversal. Loop continues until we reach the last item in the sequence. The body of for loop is separated from the rest of the code using indentation.

# %%
# List of numbers
numbers = [6, 5, 3, 8, 4, 2, 5, 4, 11]

# variable to store the sum
running_total = 0

# iterate over the list
for val in numbers:
    running_total += val

print("The sum is", running_total)

# %% [markdown]
# We can generate a sequence of numbers using `range()` function. `range(10)` will generate numbers from 0 to 9 (10 numbers). We can also define the start, stop and step size as `range(start, stop,step_size)`. step_size defaults to 1 if not provided.

# %%
print(range(10))
print(list(range(10)))
print(list(range(2, 8)))
print(list(range(2, 20, 3)))

# %% [markdown]
# We can use the range() function in for loops to iterate through a sequence of numbers. It can be combined with the len() function to iterate through a sequence using indexing. Here is an example.

# %%
genre = ['pop', 'rock', 'jazz']

# iterate over the list using index
for i in range(len(genre)):
    print("I like", genre[i])

# %% [markdown]
# A for loop can have an optional `else` block as well. The `else` part is executed if the items in the sequence used in for loop exhausts. The `break` keyword can be used to stop a for loop. In such cases, the `else` part is ignored.

# %%
digits = [0, 1, 5]

for i in digits:
    print(i)
else:
    print("No items left.")

# %%
# program to display student's marks from record
student_name = 'Soyuj'

marks = {'James': 90, 'Jules': 55, 'Arthur': 77}

for student in marks:
    if student == student_name:
        print(marks[student])
        break
else:
    print('No entry with that name found.')

# %% [markdown]
# # `while` loop
#
# For more information see [Python while Loop](https://www.programiz.com/python-programming/while-loop).
#
# The while loop in Python is used to iterate over a block of code as long as the test expression (condition) is `True`. We generally use this loop when we don't know the number of times to iterate beforehand. In the while loop, test expression is checked first. The body of the loop is entered only if the test_expression evaluates to `True`. After one iteration, the test expression is checked again. This process continues until the test_expression evaluates to `False`.
#
# In the program below, the test expression will be True as long as our counter variable i is less than or equal to n (10 in our program).

# %%
# Program to add natural
# numbers up to
# total = 1+2+3+...+n

n = 10
total = 0
i = 1
while i <= n:
    total = total + i
    i = i + 1

# print the sum
print("The sum is", total)

# %% [markdown]
# Same as with for loops, while loops can also have an optional `else` block. The `else` part is executed if the condition in the while loop evaluates to `False`. The while loop can be terminated with a `break` statement. In such cases, the `else` part is ignored.

# %%
'''Example to illustrate
the use of else statement
with the while loop'''

counter = 0

while counter < 3:
    print("Inside loop")
    counter = counter + 1
else:
    print("Inside else")

# %% [markdown]
# # Functions
#
# For more information see [Python Functions](
# https://www.programiz.com/python-programming/function).
#
# In Python, a function is a group of related statements that performs a specific task. Functions help break our program into smaller and modular chunks. As our program grows larger and larger, functions make it more organized and manageable. Furthermore, it avoids repetition and makes the code reusable.
#
# Syntax:
# * Keyword `def` that marks the start of the function header.
# * A function name to uniquely identify the function.
# * Parameters (arguments) through which we pass values to a function. They are optional.
# * A colon `:` to mark the end of the function header.
# * An optional docstring, short for documentation string. It is, like a comment, ignored when running the code and used to briefly explain what a function does.
# * One or more valid python statements that make up the function body.
# * An optional `return` statement to return a value from the function.

# %%
def greet(name):
    """
    This function greets to
    the person passed in as
    a parameter
    """
    print("Hello, " + name + ". Good morning!")

# %% [markdown]
# Once we have defined a function, we can call it from another function, program, or even the Python prompt. To call a function we simply type the function name with appropriate parameters.

# %%
greet('Paul')

# %% [markdown]
# ### `return` statement
#
# The `return` statement is used to exit a function and go back to the place from where it was called. This statement can contain an expression that gets evaluated and the value is returned. If there is no expression in the statement or the return statement itself is not present inside a function, then the function will return the `None` object.

# %%
def absolute_value(num):
    """This function returns the absolute
    value of the entered number"""

    if num >= 0:
        return num
    else:
        return -num


print(absolute_value(2))
print(absolute_value(-4))

# %% [markdown]
# Scope of a variable is the portion of a program where the variable is recognized. Parameters and variables defined inside a function are not visible from outside the function. Hence, they have a local scope. The lifetime of a variable is the period throughout which the variable exists in the memory. The lifetime of variables inside a function is as long as the function executes. They are destroyed once we return from the function. Hence, a function does not remember the value of a variable from its previous calls.

# %%
def my_func():
    x = 10
    print("Value inside function:",x)

x = 20
my_func()
print("Value outside function:",x)

# %% [markdown]
# ### Arguments
#
# The function below has two parameters. Since we have called this function with two arguments, it runs smoothly and we do not get any error. If we call it with a different number of arguments, the interpreter will show an error message.

# %%
def greet(name, message):
    """This function greets to
    the person with the provided message"""
    print("Hello", name + ', ' + message)

greet("Monica", "Good morning!")

# %%
try:
    greet()
except TypeError as error:
    print(f"Expected TypeError when required arguments are omitted: {error}")

# %% [markdown]
# The function above has a fixed number of arguments. There are other ways to define a function that can take variable number of arguments. Three different forms of this type are described below.

# %% [markdown]
# #### Default arguments
#
# Function arguments can have default values in Python. We can provide a default value to an argument by using the assignment operator (=). In the function below, the parameter `name` does not have a default value and is required (mandatory) during a call. On the other hand, the parameter `message` has a default value of "Good morning!". So, it is optional during a call. If a value is provided, it will overwrite the default value.

# %%
def greet(name, message="Good morning!"):
    """
    This function greets to
    the person with the
    provided message.

    If the message is not provided,
    it defaults to "Good
    morning!"
    """

    print("Hello", name + ', ' + message)


greet("Kate")
greet("Bruce", "How do you do?")

# %% [markdown]
# #### Keyword Arguments
#
# When we call a function with some values, these values get assigned to the arguments according to their position. For example, in the above function `greet()`, when we called it as `greet("Bruce", "How do you do?")`, the value "Bruce" gets assigned to the argument `name` and similarly "How do you do?" to `message`.
#
# Python allows functions to be called using keyword arguments. When we call functions in this way, the order (position) of the arguments can be changed. Following calls to the above function are all valid and produce the same result.

# %%
# 2 keyword arguments
greet(name = "Bruce", message = "How do you do?")

# 2 keyword arguments (changed order)
greet(message = "How do you do?", name = "Bruce")

# 1 positional, 1 keyword argument
greet("Bruce", message = "How do you do?")

# %% [markdown]
# Sometimes, we do not know in advance the number of arguments that will be passed into a function. Python allows us to handle this kind of situation through function calls with an arbitrary number of arguments. In the function definition, we use an asterisk (`*`) before the parameter name to denote this kind of argument.

# %%
def greet(*names):
    """This function greets all
    the person in the names tuple."""

    # names is a tuple with arguments
    for name in names:
        print("Hello", name)


greet("Monica", "Luke", "Steve", "John")

# %% [markdown]
# # Modules
#
# For more information refer to [Python Modules](https://www.programiz.com/python-programming/modules).
#
# Modules refer to files containing Python statements and definitions. Python has tons of standard modules, which can be installed within Python and can be imported in various ways:

# %%
import math
print("The value of pi is", math.pi)

# %%
import math as m
print("The value of pi is", m.pi)

# %%
from math import pi
print("The value of pi is", pi)

# %%
from math import pi, e
print(pi)
print(e)

# %%
# Import all definitions of some module using *
from math import *
print("The value of pi is", pi)

# %% [markdown]
# **We strongly advise against the use of `import *`**!
#
# In fact, we prefer to use *qualified names* to avoid confusion when the same name is defined in multiple modules, maybe with a different implementation.

# %%
import math
result = math.sqrt(16)
print(result)

# %% [markdown]
# To avoid *too lengthy* code we may use alyases to shorten module names.

# %%
import math as mt

mt.sqrt(16)

# %%
d = {
    1:'one',
    2:'two',
    'key':5,
    'x':'y'
}

# Using .get() with a default value
print("Using .get():")
print("d.get('x') =", d.get('x'))
print("d.get('y') =", d.get('y')) # Key 'y' does not exist, returns None by default
print("d.get('y', 'Key not found') =", d.get('y', 'Key not found')) # Key 'y' does not exist, returns the specified default

# Using the 'in' operator to check for key existence
print("\nUsing 'in' operator:")
if 'x' in d:
    print("'x' is in the dictionary, d['x'] =", d['x'])
else:
    print("'x' is not in the dictionary")

if 'y' in d:
    print("'y' is in the dictionary, d['y'] =", d['y'])
else:
    print("'y' is not in the dictionary")

# %% [markdown]
# ## Explain it without the notebook
#
# Close the code and explain one example in your own words. Predict the effect of a small change before testing it.
#
# > **Optional UvA AI Chat prompt:** Act as a Socratic tutor. Ask me one question at a time about the example I paste below. First ask for my prediction and reasoning. Give a small hint if I am stuck; do not produce a complete solution unless I explicitly ask after attempting it. Check my explanation, not just my final number.
#
# An AI response is not evidence that a result is correct. Verify it with the mathematical model and independent checks. See the [Socratic method](https://en.wikipedia.org/wiki/Socratic_method).
